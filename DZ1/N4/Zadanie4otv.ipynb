# %% [raw]
# Задание 4
# 1)sent_tokenize, как мне показалось, разбивает на предложения лучше, так как mystem порой пропускает часть слов.
# 2)Думаю, для морфологичегоского анализа лучше подходит моя регулярка, так как она охватывает слова с дефисами и избавляется от знаков препинания, не особо здесь нужных.
# 3)Mystem удобнее и нагляднее, так как может лемматизировать сырой текст, однако pymorphy предлагает несколько вариантов на лемму одного слова, что повышает его эффективность. Думаю, из-за того, что pymorphy работает с готовыми токенами, его качество сильно зависит от метода токенизации.
#
# Вообще, единственное преимущество mystem, на мой взгляд - это его умение делать всё и сразу, тогда как отдельно взятые его функции работают хуже, чем аналогичные операции других анализаторов.
